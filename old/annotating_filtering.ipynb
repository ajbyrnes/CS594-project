# %%
import numpy as np
import pandas as pd

pd.options.mode.copy_on_write = True

# %% [markdown]
# # PLAsTiCC Astronomical Data
# - `object_id` -- Unique identifier, `int32`
# - `mjd` -- Modified Julian Date, time of observation, `float64`
# - `passband` -- Specific LSST passband integer, `int8`
# - `flux` -- Measured flux in the passband observation, `float32`
# - `flux_err` -- Uncertainty on `flux`, `float32`
# - `detected` -- Whether object's brightness is significantly different at 3-sigma level relative to reference template, `bool`

# %%
# Load test data
dtypes = {
    'object_id': np.int32,
    'mjd': np.float64,
    'passband': np.int8,
    'flux': np.float32,
    'flux_err': np.float32,
    'detected': np.bool_
}

batch1_rows = 10855959
batch2_rows = 44281696
sample_rows = 1000001

df = pd.read_csv('data/test_set_batch1.csv', dtype=dtypes, nrows=1000000)
# df = pd.read_csv('data/test_set_batch2.csv', dtype=dtypes)
# df = pd.read_csv('data/test_set_sample.csv', dtype=dtypes)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count    Dtype
# ---  ------        --------------    -----
#  0   index         1000000 non-null  int64
#  1   object_id     1000000 non-null  int32
#  2   mjd           1000000 non-null  float64
#  3   passband      1000000 non-null  int8
#  4   flux          1000000 non-null  float32
#  5   flux_err      1000000 non-null  float32
#  6   detected      1000000 non-null  bool
#  7   passband_str  1000000 non-null  object
# dtypes: bool(1), float32(2), float64(1), int32(1), int64(1), int8(1), object(1)
# memory usage: 36.2+ MB

# %%
def column_memory_info(df):
    mem_ser = df.memory_usage(index=True, deep=True).apply(lambda x: x / (1024**2))
    mem_df = pd.DataFrame(mem_ser, columns=['col_MB'])
    
    mem_df['dtype'] = df.dtypes
    mem_df.loc['Index', 'dtype'] = str(df.index.dtype)
    
    mem_df['num_objects'] = df.count()
    mem_df.loc['Index', 'num_objects'] = df.index.size
    mem_df['num_objects'] = mem_df['num_objects'].astype(int)    
    return mem_df

column_memory_info(df)
# Out:
#                  col_MB    dtype  num_objects
# Index          0.000126    int64      1000000
# index          7.629395    int64      1000000
# object_id      3.814697    int32      1000000
# mjd            7.629395  float64      1000000
# passband       0.953674     int8      1000000
# flux           3.814697  float32      1000000
# flux_err       3.814697  float32      1000000
# detected       0.953674     bool      1000000
# passband_str  53.032151   object      1000000

# %%
df.nunique()
# Out:
# index           1000000
# object_id          3036
# mjd                1638
# passband              6
# flux             949056
# flux_err         821938
# detected              2
# passband_str          6
# dtype: int64

# %%
# Define intervals for object ids
object_id_intervals = df['object_id'].unique()

# %%
# Define intervals for mjd
print(df['mjd'].min(), df['mjd'].max())
print(df['flux'].min(), df['flux'].max())
print(df['flux_err'].min(), df['flux_err'].max())

df['mjd_annot'] = pd.cut(df['mjd'], bins=10)
df['mjd_annot_int'] = df['mjd_annot'].cat.codes.astype(np.int8)

df['flux_annot'] = pd.cut(df['flux'], bins=10)
df['flux_err_annot'] = pd.cut(df['flux_err'], bins=10)
df
# Out:
# 59582.3282 60674.0798
# -10383.8935546875 39288.9453125
# 0.46375399827957153 186.75535583496094
#          index  object_id         mjd  passband      flux  flux_err  detected  \
# 0            0         13  59798.3205         2 -1.299735  1.357315     False
# 1            1         13  59798.3281         1 -2.095392  1.148654     False
# 2            2         13  59798.3357         3 -0.923794  1.763655     False
# 3            3         13  59798.3466         4 -4.009815  2.602911     False
# 4            4         13  59798.3576         5 -3.403503  5.367328     False
# ...        ...        ...         ...       ...       ...       ...       ...
# 999995  999995      32300  60583.1640         0 -0.295705  3.016026     False
# 999996  999996      32300  60584.1591         0 -1.179237  2.365768     False
# 999997  999997      32300  60585.1601         0 -1.001320  1.888240     False
# 999998  999998      32300  60586.1564         0  3.691630  1.857002     False
# 999999  999999      32300  60587.1540         0 -0.621162  2.145798     False
#
#        passband_str               mjd_annot  mjd_annot_int  \
# 0               red  (59691.503, 59800.679]              1
# 1             green  (59691.503, 59800.679]              1
# 2          infrared  (59691.503, 59800.679]              1
# 3            near-z  (59691.503, 59800.679]              1
# 4            near-y  (59691.503, 59800.679]              1
# ...             ...                     ...            ...
# 999995  ultraviolet   (60564.905, 60674.08]              9
# 999996  ultraviolet   (60564.905, 60674.08]              9
# 999997  ultraviolet   (60564.905, 60674.08]              9
# 999998  ultraviolet   (60564.905, 60674.08]              9
# 999999  ultraviolet   (60564.905, 60674.08]              9
#
#                   flux_annot   flux_err_annot
# 0       (-449.326, 4517.958]  (0.277, 19.093]
# 1       (-449.326, 4517.958]  (0.277, 19.093]
# 2       (-449.326, 4517.958]  (0.277, 19.093]
# 3       (-449.326, 4517.958]  (0.277, 19.093]
# 4       (-449.326, 4517.958]  (0.277, 19.093]
# ...                      ...              ...
# 999995  (-449.326, 4517.958]  (0.277, 19.093]
# 999996  (-449.326, 4517.958]  (0.277, 19.093]
# 999997  (-449.326, 4517.958]  (0.277, 19.093]
# 999998  (-449.326, 4517.958]  (0.277, 19.093]
# 999999  (-449.326, 4517.958]  (0.277, 19.093]
#
# [1000000 rows x 12 columns]

# %%
mjd_sketch_cats = np.array([0, 2, 5])

# %%
sk1 = [0, 2, 5]

cond = ' or '.join([f'mjd_annot_int == {i}' for i in sk1])
cond
# Out:
# 'mjd_annot_int == 0 and mjd_annot_int == 2 and mjd_annot_int == 5'

# %%
sk1 = mjd_sketch_cats
sk2 = [4, 3, 7]
sk3 = [1, 6, 8]

col1 = 'mjd_annot'
col2 = 'flux_annot'
col3 = 'flux_err_annot'

sketches = [sk1, sk2, sk3]
columns = [col1, col2, col3]

cond = ' and '.join(f'{col}.cat.codes in @sketches[{i}]' for i, col in enumerate(columns))
df.query(cond)
# cond
# Out:
#          index  object_id         mjd  passband         flux   flux_err  \
# 37445    37445       1063  59896.0992         3  5907.763184  28.547117
# 37446    37446       1063  59896.1101         4  4584.966797  22.460413
# 37513    37513       1063  60192.3192         4  7017.147949  33.507481
# 37514    37514       1063  60192.3301         5  6532.176270  33.086098
# 37533    37533       1063  60212.2409         4  6871.523438  32.845257
# 37534    37534       1063  60212.2519         5  6423.333496  32.625515
# 133651  133651       4025  60183.2922         4  5624.978027  27.545336
# 133652  133652       4025  60183.3031         5  7454.176270  37.345146
# 133665  133665       4025  60209.1965         3  7008.894043  34.657139
# 133670  133670       4025  60212.1830         3  4820.763184  24.084248
# 133671  133671       4025  60212.1941         4  7439.384277  36.069500
# 275811  275811       8442  59870.0272         1  5526.817383  32.603271
# 275865  275865       8442  60168.1337         1  5436.303223  32.242302
# 275887  275887       8442  60197.1258         1  4541.773926  27.415062
# 275919  275919       8442  60227.0228         1  4919.857910  29.424665
# 378559  378559      11786  59825.2752         3  6811.047363  32.758957
# 378560  378560      11786  59825.2862         4  5414.192871  26.246717
# 378561  378561      11786  59825.2971         5  4938.078613  26.500080
# 378578  378578      11786  59857.1879         2  6552.823242  31.805601
# 378579  378579      11786  59857.1956         1  6138.619629  31.121113
# 378580  378580      11786  59857.2032         3  4777.993164  23.411734
# 378593  378593      11786  59873.1442         2  5785.446777  28.164780
# 378594  378594      11786  59873.1519         1  5288.099121  26.993233
# 810284  810284      26083  60165.1446         1  5543.051270  31.457130
#
#         detected passband_str               mjd_annot  mjd_annot_int  \
# 37445       True     infrared  (59800.679, 59909.854]              2
# 37446       True       near-z  (59800.679, 59909.854]              2
# 37513       True       near-z  (60128.204, 60237.379]              5
# 37514       True       near-y  (60128.204, 60237.379]              5
# 37533       True       near-z  (60128.204, 60237.379]              5
# 37534       True       near-y  (60128.204, 60237.379]              5
# 133651      True       near-z  (60128.204, 60237.379]              5
# 133652      True       near-y  (60128.204, 60237.379]              5
# 133665      True     infrared  (60128.204, 60237.379]              5
# 133670      True     infrared  (60128.204, 60237.379]              5
# 133671      True       near-z  (60128.204, 60237.379]              5
# 275811      True        green  (59800.679, 59909.854]              2
# 275865      True        green  (60128.204, 60237.379]              5
# 275887      True        green  (60128.204, 60237.379]              5
# 275919      True        green  (60128.204, 60237.379]              5
# 378559      True     infrared  (59800.679, 59909.854]              2
# 378560      True       near-z  (59800.679, 59909.854]              2
# 378561      True       near-y  (59800.679, 59909.854]              2
# 378578      True          red  (59800.679, 59909.854]              2
# 378579      True        green  (59800.679, 59909.854]              2
# 378580      True     infrared  (59800.679, 59909.854]              2
# 378593      True          red  (59800.679, 59909.854]              2
# 378594      True        green  (59800.679, 59909.854]              2
# 810284      True        green  (60128.204, 60237.379]              5
#
#                   flux_annot    flux_err_annot
# 37445   (4517.958, 9485.242]  (19.093, 37.722]
# 37446   (4517.958, 9485.242]  (19.093, 37.722]
# 37513   (4517.958, 9485.242]  (19.093, 37.722]
# 37514   (4517.958, 9485.242]  (19.093, 37.722]
# 37533   (4517.958, 9485.242]  (19.093, 37.722]
# 37534   (4517.958, 9485.242]  (19.093, 37.722]
# 133651  (4517.958, 9485.242]  (19.093, 37.722]
# 133652  (4517.958, 9485.242]  (19.093, 37.722]
# 133665  (4517.958, 9485.242]  (19.093, 37.722]
# 133670  (4517.958, 9485.242]  (19.093, 37.722]
# 133671  (4517.958, 9485.242]  (19.093, 37.722]
# 275811  (4517.958, 9485.242]  (19.093, 37.722]
# 275865  (4517.958, 9485.242]  (19.093, 37.722]
# 275887  (4517.958, 9485.242]  (19.093, 37.722]
# 275919  (4517.958, 9485.242]  (19.093, 37.722]
# 378559  (4517.958, 9485.242]  (19.093, 37.722]
# 378560  (4517.958, 9485.242]  (19.093, 37.722]
# 378561  (4517.958, 9485.242]  (19.093, 37.722]
# 378578  (4517.958, 9485.242]  (19.093, 37.722]
# 378579  (4517.958, 9485.242]  (19.093, 37.722]
# 378580  (4517.958, 9485.242]  (19.093, 37.722]
# 378593  (4517.958, 9485.242]  (19.093, 37.722]
# 378594  (4517.958, 9485.242]  (19.093, 37.722]
# 810284  (4517.958, 9485.242]  (19.093, 37.722]

# %%
# df.query('mjd_annot.cat.codes in @mjd_sketch_cats')

# %%
# df[df['mjd_annot'].cat.codes.isin(mjd_sketch_cats)]

# %%
# %%timeit
df[df['mjd_annot'].cat.codes.isin(mjd_sketch_cats)]
# Out:
# 30 ms ± 4.75 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit 
df[np.isin(df['mjd_annot'].cat.codes.values, mjd_sketch_cats)]
# Out:
# 24.7 ms ± 3.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
df[df['mjd_annot_int'].isin(mjd_sketch_cats)]
# Out:
# 29.4 ms ± 2.66 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
df.loc[df['mjd_annot_int'].isin(mjd_sketch_cats)]
# Out:
# 32.6 ms ± 5.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
df.query('mjd_annot_int in @mjd_sketch_cats')
# Out:
# 41.5 ms ± 4.14 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
sketch = mjd_sketch_cats
df.query('mjd_annot_int in @sketch')
# Out:
#          index  object_id         mjd  passband      flux  flux_err  detected  \
# 5            5         13  59801.3553         2 -1.778855  2.448943     False
# 6            6         13  59801.3629         1  2.491993  3.540421     False
# 7            7         13  59801.3705         3  1.644129  2.284999     False
# 8            8         13  59801.3815         4 -0.158192  2.515900     False
# 9            9         13  59801.3924         5 -6.457387  5.381231     False
# ...        ...        ...         ...       ...       ...       ...       ...
# 999907  999907      32300  60226.3337         2  0.991051  0.951415     False
# 999908  999908      32300  60226.3413         1 -0.170953  0.953229     False
# 999909  999909      32300  60226.3489         3  2.333871  1.803218     False
# 999910  999910      32300  60226.3599         4 -3.905768  3.082055     False
# 999911  999911      32300  60226.3708         5 -2.617442  8.135333     False
#
#        passband_str               mjd_annot  mjd_annot_int
# 5               red  (59800.679, 59909.854]              2
# 6             green  (59800.679, 59909.854]              2
# 7          infrared  (59800.679, 59909.854]              2
# 8            near-z  (59800.679, 59909.854]              2
# 9            near-y  (59800.679, 59909.854]              2
# ...             ...                     ...            ...
# 999907          red  (60128.204, 60237.379]              5
# 999908        green  (60128.204, 60237.379]              5
# 999909     infrared  (60128.204, 60237.379]              5
# 999910       near-z  (60128.204, 60237.379]              5
# 999911       near-y  (60128.204, 60237.379]              5
#
# [417617 rows x 10 columns]

# %% [markdown]
# # MultiIndex

# %%
# MultiIndex and then filter
mi = pd.MultiIndex.from_arrays([df['mjd_annot'].cat.codes, df['object_id']], names=['mjd_cat', 'object_id'])
df_mi = df.set_index(mi).sort_index()
df_mi
# Out:
#                     index  object_id         mjd  passband        flux  \
# mjd_cat object_id
# 0       96           3782         96  59582.3282         0   40.029842
#         96           3783         96  59583.2409         0   63.055912
#         96           3784         96  59584.2432         0   84.849129
#         96           3785         96  59585.2363         0  110.552193
#         96           3786         96  59586.2371         0  134.320419
# ...                   ...        ...         ...       ...         ...
# 9       32300      999995      32300  60583.1640         0   -0.295705
#         32300      999996      32300  60584.1591         0   -1.179237
#         32300      999997      32300  60585.1601         0   -1.001320
#         32300      999998      32300  60586.1564         0    3.691630
#         32300      999999      32300  60587.1540         0   -0.621162
#
#                    flux_err  detected passband_str               mjd_annot  \
# mjd_cat object_id
# 0       96         2.979331      True  ultraviolet  (59581.236, 59691.503]
#         96         2.795795      True  ultraviolet  (59581.236, 59691.503]
#         96         2.927637      True  ultraviolet  (59581.236, 59691.503]
#         96         3.367064      True  ultraviolet  (59581.236, 59691.503]
#         96         3.861461      True  ultraviolet  (59581.236, 59691.503]
# ...                     ...       ...          ...                     ...
# 9       32300      3.016026     False  ultraviolet   (60564.905, 60674.08]
#         32300      2.365768     False  ultraviolet   (60564.905, 60674.08]
#         32300      1.888240     False  ultraviolet   (60564.905, 60674.08]
#         32300      1.857002     False  ultraviolet   (60564.905, 60674.08]
#         32300      2.145798     False  ultraviolet   (60564.905, 60674.08]
#
#                    mjd_annot_int
# mjd_cat object_id
# 0       96                     0
#         96                     0
#         96                     0
#         96                     0
#         96                     0
# ...                          ...
# 9       32300                  9
#         32300                  9
#         32300                  9
#         32300                  9
#         32300                  9
#
# [1000000 rows x 10 columns]

# %%
# %%timeit
sketch = mjd_sketch_cats
df_mi.index
# Out:
# MultiIndex([(0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             ...
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300)],
#            names=['mjd_cat', 'object_id'], length=1000000)

# %%
# %%timeit
df_mi.loc[mjd_sketch_cats]
# Out:
#                     index  object_id         mjd  passband        flux  \
# mjd_cat object_id
# 0       96           3782         96  59582.3282         0   40.029842
#         96           3783         96  59583.2409         0   63.055912
#         96           3784         96  59584.2432         0   84.849129
#         96           3785         96  59585.2363         0  110.552193
#         96           3786         96  59586.2371         0  134.320419
# ...                   ...        ...         ...       ...         ...
# 5       32300      999907      32300  60226.3337         2    0.991051
#         32300      999908      32300  60226.3413         1   -0.170953
#         32300      999909      32300  60226.3489         3    2.333871
#         32300      999910      32300  60226.3599         4   -3.905768
#         32300      999911      32300  60226.3708         5   -2.617442
#
#                    flux_err  detected passband_str               mjd_annot  \
# mjd_cat object_id
# 0       96         2.979331      True  ultraviolet  (59581.236, 59691.503]
#         96         2.795795      True  ultraviolet  (59581.236, 59691.503]
#         96         2.927637      True  ultraviolet  (59581.236, 59691.503]
#         96         3.367064      True  ultraviolet  (59581.236, 59691.503]
#         96         3.861461      True  ultraviolet  (59581.236, 59691.503]
# ...                     ...       ...          ...                     ...
# 5       32300      0.951415     False          red  (60128.204, 60237.379]
#         32300      0.953229     False        green  (60128.204, 60237.379]
#         32300      1.803218     False     infrared  (60128.204, 60237.379]
#         32300      3.082055     False       near-z  (60128.204, 60237.379]
#         32300      8.135333     False       near-y  (60128.204, 60237.379]
#
#                    mjd_annot_int
# mjd_cat object_id
# 0       96                     0
#         96                     0
#         96                     0
#         96                     0
#         96                     0
# ...                          ...
# 5       32300                  5
#         32300                  5
#         32300                  5
#         32300                  5
#         32300                  5
#
# [417617 rows x 10 columns]

# %%
# %%timeit
df_mi.loc[pd.IndexSlice[mjd_sketch_cats, :]]
# Out:
#                     index  object_id         mjd  passband        flux  \
# mjd_cat object_id
# 0       96           3782         96  59582.3282         0   40.029842
#         96           3783         96  59583.2409         0   63.055912
#         96           3784         96  59584.2432         0   84.849129
#         96           3785         96  59585.2363         0  110.552193
#         96           3786         96  59586.2371         0  134.320419
# ...                   ...        ...         ...       ...         ...
# 5       32300      999907      32300  60226.3337         2    0.991051
#         32300      999908      32300  60226.3413         1   -0.170953
#         32300      999909      32300  60226.3489         3    2.333871
#         32300      999910      32300  60226.3599         4   -3.905768
#         32300      999911      32300  60226.3708         5   -2.617442
#
#                    flux_err  detected passband_str               mjd_annot  \
# mjd_cat object_id
# 0       96         2.979331      True  ultraviolet  (59581.236, 59691.503]
#         96         2.795795      True  ultraviolet  (59581.236, 59691.503]
#         96         2.927637      True  ultraviolet  (59581.236, 59691.503]
#         96         3.367064      True  ultraviolet  (59581.236, 59691.503]
#         96         3.861461      True  ultraviolet  (59581.236, 59691.503]
# ...                     ...       ...          ...                     ...
# 5       32300      0.951415     False          red  (60128.204, 60237.379]
#         32300      0.953229     False        green  (60128.204, 60237.379]
#         32300      1.803218     False     infrared  (60128.204, 60237.379]
#         32300      3.082055     False       near-z  (60128.204, 60237.379]
#         32300      8.135333     False       near-y  (60128.204, 60237.379]
#
#                    mjd_annot_int
# mjd_cat object_id
# 0       96                     0
#         96                     0
#         96                     0
#         96                     0
#         96                     0
# ...                          ...
# 5       32300                  5
#         32300                  5
#         32300                  5
#         32300                  5
#         32300                  5
#
# [417617 rows x 10 columns]

# %%
df_mi.index
# Out:
# MultiIndex([(0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             (0,    96),
#             ...
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300),
#             (9, 32300)],
#            names=['mjd_cat', 'object_id'], length=1000000)

# %% [markdown]
# # Groupby

# %%
# %%timeit
df.groupby(df['mjd_annot'].cat.codes).indices
# pd.concat([df.loc[df.groupby(df['mjd_annot'].cat.codes).groups[mjd_cat]] for mjd_cat in mjd_sketch_cats])
# Out:
# 36.1 ms ± 6.96 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
